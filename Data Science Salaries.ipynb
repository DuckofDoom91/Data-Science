# %%
import pandas as pd
data_frame = pd.read_csv('ds_salaries.csv')
data_frame.shape
# Out:
# (607, 12)

# %%
data_frame
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# ### Question to Solve: What Job has the best pay as a remote postion.

# %%
df1 = pd.DataFrame(data_frame, columns=['job_title', 'remote_ratio', 'salary_in_usd'])
df1
# Out:
#                       job_title  remote_ratio  salary_in_usd
# 0                Data Scientist             0          79833
# 1    Machine Learning Scientist             0         260000
# 2             Big Data Engineer            50         109024
# 3          Product Data Analyst             0          20000
# 4     Machine Learning Engineer            50         150000
# ..                          ...           ...            ...
# 602               Data Engineer           100         154000
# 603               Data Engineer           100         126000
# 604                Data Analyst             0         129000
# 605                Data Analyst           100         150000
# 606                AI Scientist           100         200000
#
# [607 rows x 3 columns]

# %%
df1.sort_values('remote_ratio', ascending=False)
# Out:
#                      job_title  remote_ratio  salary_in_usd
# 303             Data Scientist           100         123000
# 401              Data Engineer           100         154600
# 399             Data Scientist           100         158200
# 398             Data Scientist           100         215300
# 396  Machine Learning Engineer           100          87932
# ..                         ...           ...            ...
# 403               Data Analyst             0          81666
# 405              Data Engineer             0          98158
# 406               Data Analyst             0          58000
# 150   Director of Data Science             0         168000
# 0               Data Scientist             0          79833
#
# [607 rows x 3 columns]

# %%
df1 = df1.loc[df1["remote_ratio"] > 99]
df1
# Out:
#                  job_title  remote_ratio  salary_in_usd
# 5             Data Analyst           100          72000
# 6      Lead Data Scientist           100         190000
# 8    Business Data Analyst           100         135000
# 13       Lead Data Analyst           100          87000
# 14            Data Analyst           100          85000
# ..                     ...           ...            ...
# 599         Data Scientist           100         130000
# 602          Data Engineer           100         154000
# 603          Data Engineer           100         126000
# 605           Data Analyst           100         150000
# 606           AI Scientist           100         200000
#
# [381 rows x 3 columns]

# %%
df1.dtypes
# Out:
# job_title        object
# remote_ratio      int64
# salary_in_usd     int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

# %%
df1
# Out:
#                  job_title  remote_ratio  salary_in_usd
# 5             Data Analyst           100          72000
# 6      Lead Data Scientist           100         190000
# 8    Business Data Analyst           100         135000
# 13       Lead Data Analyst           100          87000
# 14            Data Analyst           100          85000
# ..                     ...           ...            ...
# 599         Data Scientist           100         130000
# 602          Data Engineer           100         154000
# 603          Data Engineer           100         126000
# 605           Data Analyst           100         150000
# 606           AI Scientist           100         200000
#
# [381 rows x 3 columns]

# %%
df2 = df1.groupby('job_title')["salary_in_usd"].mean()
df2
# Out:
# job_title
# AI Scientist                                 59410.600000
# Analytics Engineer                          155000.000000
# Applied Data Scientist                      238000.000000
# Applied Machine Learning Scientist           48425.000000
# BI Data Analyst                              86424.000000
# Big Data Engineer                            66758.333333
# Business Data Analyst                        78136.000000
# Cloud Data Engineer                         160000.000000
# Computer Vision Engineer                     31333.333333
# Computer Vision Software Engineer           105248.666667
# Data Analyst                                 99319.785714
# Data Analytics Engineer                      79732.333333
# Data Analytics Lead                         405000.000000
# Data Analytics Manager                      128323.333333
# Data Architect                              177873.909091
# Data Engineer                               122060.795699
# ...

# %%
df2 = pd.DataFrame(df2.reset_index(name = "Avg. Salary"))

# %%
df2 = df2.round(decimals = 2)
df2
# Out:
#                                    job_title  Avg. Salary
# 0                               AI Scientist     59410.60
# 1                         Analytics Engineer    155000.00
# 2                     Applied Data Scientist    238000.00
# 3         Applied Machine Learning Scientist     48425.00
# 4                            BI Data Analyst     86424.00
# 5                          Big Data Engineer     66758.33
# 6                      Business Data Analyst     78136.00
# 7                        Cloud Data Engineer    160000.00
# 8                   Computer Vision Engineer     31333.33
# 9          Computer Vision Software Engineer    105248.67
# 10                              Data Analyst     99319.79
# 11                   Data Analytics Engineer     79732.33
# 12                       Data Analytics Lead    405000.00
# 13                    Data Analytics Manager    128323.33
# 14                            Data Architect    177873.91
# ...

# %%
# %matplotlib inline
from matplotlib.pyplot import figure

# %%
df2.plot(x='job_title', y='Avg. Salary', kind='bar')
figure(figsize=(8, 6), dpi=80)

# %%
df2.plot.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12164/2642527296.py in <module>
# ----> 1 df2.plot.show
#
# AttributeError: 'PlotAccessor' object has no attribute 'show'
